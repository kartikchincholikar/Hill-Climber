# %%
import numpy as np
from terrain import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,100,1)

# %%
y = 4*x

# %%
w = np.arange(-20,19,1)

# %%
w = w.reshape(39,1)

# %%
x = x.reshape(1,100)

# %%
m = np.matmul(w,x)

# %%
m.shape
# Out:
# (39, 100)

# %%
m = m.T

# %%
t = m - y.reshape(100,1)

# %%
t.shape
# Out:
# (100, 39)

# %%
sqr = np.square(t)

# %%
sqr
# Out:
# array([[      0,       0,       0, ...,       0,       0,       0],
#        [    576,     529,     484, ...,     144,     169,     196],
#        [   2304,    2116,    1936, ...,     576,     676,     784],
#        ...,
#        [5419584, 4977361, 4553956, ..., 1354896, 1590121, 1844164],
#        [5531904, 5080516, 4648336, ..., 1382976, 1623076, 1882384],
#        [5645376, 5184729, 4743684, ..., 1411344, 1656369, 1920996]], dtype=int32)

# %%
cost = np.sum(sqr,axis = 0)

# %%
cost
# Out:
# array([189129600, 173697150, 158921400, 144802350, 131340000, 118534350,
#        106385400,  94893150,  84057600,  73878750,  64356600,  55491150,
#         47282400,  39730350,  32835000,  26596350,  21014400,  16089150,
#         11820600,   8208750,   5253600,   2955150,   1313400,    328350,
#                0,    328350,   1313400,   2955150,   5253600,   8208750,
#         11820600,  16089150,  21014400,  26596350,  32835000,  39730350,
#         47282400,  55491150,  64356600], dtype=int32)

# %%
plt.scatter(np.arange(39),cost)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %%
x = np.arange(0,10)
y = 10*x + np.random.normal(0,1,x.shape)

# %%
get_costs(8,10,x,y)
# Out:
# [  1.27369474e+03   3.57607116e+02   1.15194868e+01   2.35431858e+02
#    1.02934423e+03   2.39325660e+03   4.32716897e+03   6.83108134e+03
#    9.90499371e+03   1.35489061e+04]
